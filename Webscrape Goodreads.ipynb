# %%
#instantiate cursor and load libraries
import json
import pandas as pd
import requests
import mysql.connector
import config
import time
import requests
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
from bs4 import BeautifulSoup as BS

# %% [markdown]
# # Scrape 2019

# %%
books_2019 = []
years = [2019]
genres = ['debut-novel','young-adult-fiction-books', 'young-adult-fantasy-books', 'childrens-books', 
          'picture-books','fiction-books', 'mystery-thriller-books', 'historical-fiction-books', 'fantasy-books', 
          'romance-books', 'science-fiction-books', 'horror-books', 'humor-books', 'nonfiction-books',
          'memoir-autobiography-books', 'history-biography-books', 'science-technology-books',
          'food-cookbooks', 'graphic-novels-comics', 'poetry-books']

def get_2019books():
    
    for year in years:
        
        print(year)
        
        for genre in genres:
            
            print(genre)
            
            url = f'https://www.goodreads.com/choiceawards/best-{genre}-{year}'
            resp = urllib.request.urlopen(url)
            soup = BS(resp, from_encoding=resp.info().get_param('charset'))
            
            for info in soup.find_all(href=True):
#                 print(info)

                if 'from_choice=true' in info['href']:
                    end_url = info['href']

                    each_book = {}

                    resp = urllib.request.urlopen(f'https://www.goodreads.com{end_url}')
                    content = BS(resp, 'html.parser')

                    each_book['title'] = get_title(content)
                    each_book['author'] = get_author(content)
                    each_book['rating'] = get_rating(content)
                    each_book['pages'] = get_pages(content)
                    each_book['publisher'] = get_publisher(content)
                    each_book['ISBN'] = get_ISBN(content)
                    each_book['genre'] = get_genre(content)
                    each_book['series'] = get_series(content)
                    each_book['author_followers'] = get_followers(content)
                    each_book['publish_date'] = get_release_date(content)

                    books_2019.append(each_book)

                    print(f"Inserted {each_book['title']}")

    pd.DataFrame(books_2019).to_csv('books_2019.csv')

    return books_2019

# %%
get_2019books()
# Out:
# 2019
# debut-novel
# Inserted Red, White & Royal Blue
# Inserted Red, White & Royal Blue
# Inserted Red, White & Royal Blue
# Inserted The Silent Patient
# Inserted My Sister, the Serial Killer
# Inserted The Ten Thousand Doors of January
# Inserted The Water Dancer
# Inserted Evvie Drake Starts Over
# Inserted On Earth We're Briefly Gorgeous
# Inserted A Woman Is No Man
# Inserted The Secrets We Kept
# Inserted Queenie
# Inserted Serpent & Dove
# Inserted Miracle Creek
# Inserted The Most Fun We Ever Had
# Inserted Boy Swallows Universe
# Inserted When All Is Said
# Inserted House of Salt and Sorrows
# Inserted We Hunt the Flame
# Inserted Gideon the Ninth
# Inserted The Friend Zone
# Inserted Fleishman Is in Trouble
# young-adult-fiction-books
# Inserted Five Feet Apart
# Inserted Five Feet Apart
# Inserted Five Feet Apart
# Inserted On the Come Up
# Inserted With the Fire on High
# Inserted Two Can Keep a Secret
# Inserted The Fountains of Silence
# Inserted Again, but Better
# Inserted I Wish You All the Best
# Inserted The Vanishing Stair
# Inserted American Royals
# Inserted The Rest of the Story
# Inserted Capturing the Devil
# Inserted Internment
# Inserted The Princess and the Fangirl
# Inserted Frankly in Love
# Inserted Serious Moonlight
# Inserted Opposite of Always
# Inserted The Grace Year
# Inserted Lovely War
# Inserted Love From A to Z
# Inserted Birthday
# young-adult-fantasy-books
# Inserted The Wicked King
# Inserted The Wicked King
# Inserted The Wicked King
# Inserted Wayward Son
# Inserted Queen of Air and Darkness
# Inserted King of Scars
# Inserted Wilder Girls
# Inserted The Toll
# Inserted A Curse So Dark and Lonely
# Inserted Finale
# Inserted Sorcery of Thorns
# Inserted Aurora Rising
# Inserted Supernova
# Inserted Defy Me
# Inserted Bloodwitch
# Inserted Call Down the Hawk
# Inserted Four Dead Queens
# Inserted Rebel
# Inserted The Secret Commonwealth
# Inserted Serpent & Dove
# Inserted We Hunt the Flame
# Inserted The Gilded Wolves
# childrens-books
# Inserted The Tyrant's Tomb
# Inserted The Tyrant's Tomb
# Inserted The Tyrant's Tomb
# Inserted Tunnel of Bones
# Inserted Guts
# Inserted The Remarkable Journey of Coyote Sunrise
# Inserted New Kid
# Inserted A Crystal of Time
# Inserted Dragon Pearl
# Inserted Diary of an Awesome Friendly Kid: Rowley Jefferson's Journal
# Inserted The Strangers
# Inserted Aru Shah and the Song of Death
# Inserted The Bridge Home
# Inserted Other Words for Home
# Inserted Legacy
# Inserted Shouting at the Rain
# Inserted To Night Owl from Dogfish
# Inserted Dead Voices
# Inserted The Unteachables
# Inserted A Tale of Magic...
# Inserted Dear Sweet Pea
# Inserted Tristan Strong Punches a Hole in the Sky
# picture-books
# Inserted A Beautiful Day in the Neighborhood: The Poetry of Mister Rogers
# Inserted A Beautiful Day in the Neighborhood: The Poetry of Mister Rogers
# Inserted A Beautiful Day in the Neighborhood: The Poetry of Mister Rogers
# Inserted Sulwe
# Inserted The Good Egg
# Inserted Hair Love
# Inserted Unicorn Day
# Inserted A Tiger Like Me
# Inserted Because
# Inserted We Are (Not) Friends
# Inserted Just Because
# Inserted A Piglet Named Mercy
# Inserted Pirates Don't Go to Kindergarten!
# Inserted The Proudest Blue
# Inserted How to Read a Book
# Inserted It's Not Hansel and Gretel
# Inserted Fry Bread: A Native American Family Story
# Inserted What If Everybody Thought That?
# Inserted Vacation for Dexter!
# Inserted The Undefeated
# Inserted Rosie the Dragon and Charlie Make Waves
# Inserted Snow Globe Wishes
# fiction-books
# Inserted The Testaments
# Inserted The Testaments
# Inserted The Testaments
# Inserted Normal People
# Inserted Where the Forest Meets the Stars
# Inserted Ask Again, Yes
# Inserted Queenie
# Inserted On Earth We're Briefly Gorgeous
# Inserted A Woman Is No Man
# Inserted The Overdue Life of Amy Byler
# Inserted Olive, Again
# Inserted The Most Fun We Ever Had
# Inserted The Bookish Life of Nina Hill
# Inserted The Last Romantics
# Inserted Red at the Bone
# Inserted When All Is Said
# Inserted The Gifted School
# Inserted Fleishman Is in Trouble
# Inserted Find Me
# Inserted The Reckless Oath We Made
# Inserted Girl, Woman, Other
# Inserted Lanny
# mystery-thriller-books
# Inserted The Silent Patient
# Inserted The Silent Patient
# Inserted The Silent Patient
# Inserted My Sister, the Serial Killer
# Inserted The Turn of the Key
# Inserted The Lost Man
# Inserted An Anonymous Girl
# Inserted The Whisper Man
# Inserted Run Away
# Inserted Lock Every Door
# Inserted Miracle Creek
# Inserted The Mother-in-Law
# Inserted A Better Man
# Inserted The Family Upstairs
# Inserted The Chain
# Inserted Disappearing Earth
# Inserted Searching for Sylvie Lee
# Inserted I'll Never Tell
# Inserted The Night Fire
# Inserted The Last Widow
# Inserted My Lovely Wife
# Inserted The Line Between
# historical-fiction-books
# Inserted Daisy Jones & The Six
# Inserted Daisy Jones & The Six
# Inserted Daisy Jones & The Six
# Inserted The Nickel Boys
# Inserted The Huntress
# Inserted City of Girls
# Inserted The Giver of Stars
# Inserted The Water Dancer
# Inserted Once Upon a River
# Inserted The Lost Girls of Paris
# Inserted The Dutch House
# Inserted Summer of '69
# Inserted The Island of Sea Women
# Inserted What the Wind Knows
# Inserted The Night Tiger
# Inserted Lost Roses
# Inserted Mrs. Everything
# Inserted Cilka's Journey
# Inserted The Book Woman of Troublesome Creek
# Inserted This Tender Land
# Inserted Nottingham
# Inserted The Summer Country
# fantasy-books
# Inserted Ninth House
# Inserted Ninth House
# Inserted Ninth House
# Inserted The Starless Sea
# Inserted Fire & Blood
# Inserted The Priory of the Orange Tree
# Inserted The Red Scrolls of Magic
# Inserted The Winter of the Witch
# Inserted Of Blood and Bone
# Inserted Storm Cursed
# Inserted Black Leopard, Red Wolf
# Inserted Middlegame
# Inserted The Ten Thousand Doors of January
# Inserted Gods of Jade and Shadow
# Inserted The Kingdom of Copper
# Inserted The Dragon Republic
# Inserted Darkdawn
# Inserted Magic for Liars
# Inserted The Burning White
# Inserted Age of Legend
# Inserted A Little Hatred
# Inserted Holy Sister
# romance-books
# Inserted Red, White & Royal Blue
# Inserted Red, White & Royal Blue
# Inserted Red, White & Royal Blue
# Inserted Verity
# Inserted The Unhoneymooners
# Inserted Things You Save in a Fire
# Inserted The Bride Test
# Inserted The Savior
# Inserted The Kiss Thief
# Inserted The Flatshare
# Inserted Pretty Reckless
# Inserted The Girl He Used to Know
# Inserted Ayesha at Last
# Inserted The Friend Zone
# Inserted The Wedding Party
# Inserted Meet Cute
# Inserted Well Met
# Inserted Sapphire Flames
# Inserted Beard Necessities
# Inserted The Best Thing
# Inserted The Wallflower Wager
# Inserted Brazen and the Beast
# science-fiction-books
# Inserted Recursion
# Inserted Recursion
# Inserted Recursion
# Inserted Dark Age
# Inserted Gideon the Ninth
# Inserted This Is How You Lose the Time War
# Inserted The Deep
# Inserted Tiamat's Wrath
# Inserted Machines Like Me
# Inserted Exhalation
# Inserted The Test
# Inserted Fall, Or Dodge in Hell
# Inserted One Word Kill
# Inserted To Be Taught, If Fortunate
# Inserted Wanderers
# Inserted The City in the Middle of the Night
# Inserted A Memory Called Empire
# Inserted Thrawn: Treason
# Inserted The Future of Another Timeline
# Inserted Here and Now and Then
# Inserted Children of Ruin
# Inserted The Light Brigade
# horror-books
# Inserted The Institute
# Inserted The Institute
# Inserted The Institute
# Inserted Imaginary Friend
# Inserted The Girl in Red
# Inserted The Invited
# Inserted The Lost Causes of Bleak Creek
# Inserted Full Throttle
# Inserted Bunny
# Inserted Wakenhyrst
# Inserted The Twisted Ones
# Inserted A Cosmology of Monsters
# Inserted No One's Home
# Inserted Growing Things and Other Stories
# Inserted Song for the Unraveling of the World
# Inserted The Toll
# Inserted Violet
# Inserted The Remaking
# Inserted The Monster of Elendhaven
# Inserted The Luminous Dead
# Inserted The Need
# Inserted Petra's Ghost
# humor-books
# Inserted Dear Girls: Intimate Tales, Untold Secrets, & Advice for Living Your Best Life
# Inserted Dear Girls: Intimate Tales, Untold Secrets, & Advice for Living Your Best Life
# Inserted Dear Girls: Intimate Tales, Untold Secrets, & Advice for Living Your Best Life
# Inserted Life Will Be the Death of Me: . . . and You Too!
# Inserted William Shakespeare's Much Ado About Mean Girls
# Inserted Do You Mind If I Cancel? (Things That Still Annoy Me)
# Inserted Southern Lady Code
# Inserted The Field Guide to Dumb Birds of North America
# Inserted Riding the Elephant: A Memoir of Altercations, Humiliations, Hallucinations, and Observations
# Inserted Hope Rides Again
# Inserted Small Doses
# Inserted A Woman First: First Woman: A Memoir
# Inserted Twas the Nightshift before Christmas
# Inserted Good Things Happen to People You Hate: Essays
# Inserted Mr. Know-It-All: The Tarnished Wisdom of a Filth Elder
# Inserted Effin' Birds: A Field Guide to Identification
# Inserted Baby, Don't Hurt Me: Stories and Scars from Saturday Night Live
# Inserted Brilliant, Brilliant, Brilliant Brilliant Brilliant
# Inserted Medallion Status: True Stories from Secret Rooms
# Inserted Nice Try: Stories of Best Intentions and Mixed Results
# Inserted When Life Gives You Pears: The Healing Power of Family, Faith, and Funny People
# Inserted Someone Who Will Love You in All Your Damaged Glory: Stories
# nonfiction-books
# Inserted Girl, Stop Apologizing: A Shame-Free Plan for Embracing and Achieving Your Goals
# Inserted Girl, Stop Apologizing: A Shame-Free Plan for Embracing and Achieving Your Goals
# Inserted Girl, Stop Apologizing: A Shame-Free Plan for Embracing and Achieving Your Goals
# Inserted Stay Sexy & Don't Get Murdered: The Definitive How-To Guide
# Inserted Maybe You Should Talk to Someone: A Therapist, Her Therapist, and Our Lives Revealed
# Inserted Catch and Kill: Lies, Spies, and a Conspiracy to Protect Predators
# Inserted Everything Is F*cked: A Book About Hope
# Inserted Talking to Strangers: What We Should Know about the People We Don't Know
# Inserted Three Women
# Inserted American Predator: The Hunt for the Most Meticulous Serial Killer of the 21st Century
# Inserted She Said: Breaking the Sexual Harassment Story That Helped Ignite a Movement
# Inserted The Moment of Lift: How Empowering Women Changes the World
# Inserted The Witches Are Coming
# Inserted Parkland: Birth of a Movement
# Inserted Embrace Your Weird: Face Your Fears and Unleash Creativity
# Inserted The Collected Schizophrenias: Essays
# Inserted Trick Mirror: Reflections on Self-Delusion
# Inserted Furious Hours: Murder, Fraud, and the Last Trial of Harper Lee
# Inserted Blowout: Corrupted Democracy, Rogue State Russia, and the Richest, Most Destructive Industry on Earth
# Inserted How to Be an Antiracist
# Inserted Thick: And Other Essays
# Inserted Grace Will Lead Us Home: The Charleston Church Massacre and the Hard, Inspiring Journey to Forgiveness
# memoir-autobiography-books
# Inserted Over the Top: A Raw Journey to Self-Love
# Inserted Over the Top: A Raw Journey to Self-Love
# Inserted Over the Top: A Raw Journey to Self-Love
# Inserted Know My Name
# Inserted Home Work: A Memoir of My Hollywood Years
# Inserted Maid: Hard Work, Low Pay, and a Mother's Will to Survive
# Inserted Me
# Inserted Inheritance: A Memoir of Genealogy, Paternity, and Love
# Inserted Inside Out
# Inserted From Scratch: A Memoir of Love, Sicily, and Finding Home
# Inserted How We Fight For Our Lives
# Inserted Toil & Trouble
# Inserted Year of the Monkey
# Inserted In the Dream House: A Memoir
# Inserted Permanent Record
# Inserted More Than Enough: Claiming Space for Who You Are (No Matter What They Say)
# Inserted Long Live the Tribe of Fatherless Girls
# Inserted Prognosis: A Memoir of My Brain
# Inserted Sounds Like Titanic
# Inserted The Unwinding of the Miracle: A Memoir of Life, Death, and Everything That Comes After
# Inserted What Is a Girl Worth?: My Story of Breaking the Silence and Exposing the Truth about Larry Nassar and USA Gymnastics
# Inserted Wild Game: My Mother, Her Lover, and Me
# history-biography-books
# Inserted The Five: The Untold Lives of the Women Killed by Jack the Ripper
# Inserted The Five: The Untold Lives of the Women Killed by Jack the Ripper
# Inserted The Five: The Untold Lives of the Women Killed by Jack the Ripper
# Inserted Midnight in Chernobyl: The Untold Story of the World's Greatest Nuclear Disaster
# Inserted Say Nothing: A True Story of Murder and Memory in Northern Ireland
# Inserted Before and After: The Incredible Real-Life Stories of Orphans Who Survived the Tennessee Children's Home Society
# Inserted A Woman of No Importance: The Untold Story of the American Spy Who Helped Win World War II
# Inserted The Only Plane in the Sky: An Oral History of 9/11
# Inserted The Pioneers: The Heroic Story of the Settlers Who Brought the American Ideal West
# Inserted First: Sandra Day O'Connor
# Inserted The First Conspiracy: The Secret Plot to Kill George Washington
# Inserted The Heartbeat of Wounded Knee: Native America from 1890 to the Present
# Inserted Madame Fourcade's Secret War: The Daring Young Woman Who Led France's Largest Spy Network Against Hitler
# Inserted How to Hide an Empire: A History of the Greater United States
# Inserted Dutch Girl: Audrey Hepburn and World War II
# Inserted The Lady from the Black Lagoon: Hollywood Monsters and the Lost Legacy of Milicent Patrick
# Inserted Code Name: Lise. The True Story of the Woman Who Became WWII's Most Highly Decorated Spy
# Inserted Upheaval: Turning Points for Nations in Crisis
# Inserted The British Are Coming: The War for America, Lexington to Princeton, 1775-1777
# Inserted Spearhead: An American Tank Gunner, His Enemy, and a Collision of Lives In World War II
# Inserted The Death and Life of Aida Hernandez: A Border Story
# Inserted The Anarchy: The East India Company, Corporate Violence, and the Pillage of an Empire
# science-technology-books
# Inserted Will My Cat Eat My Eyeballs? Big Questions from Tiny Mortals About Death
# Inserted Will My Cat Eat My Eyeballs? Big Questions from Tiny Mortals About Death
# Inserted Will My Cat Eat My Eyeballs? Big Questions from Tiny Mortals About Death
# Inserted Invisible Women: Data Bias in a World Designed for Men
# Inserted The Body: A Guide for Occupants
# Inserted How To: Absurd Scientific Advice for Common Real-World Problems
# Inserted Mama's Last Hug: Animal Emotions and What They Tell Us about Ourselves
# Inserted Digital Minimalism: Choosing a Focused Life in a Noisy World
# Inserted The Uninhabitable Earth: Life After Warming
# Inserted Underland
# Inserted Crisis in the Red Zone: The Story of the Deadliest Ebola Outbreak in History, and of the Outbreaks to Come
# Inserted We Are the Weather: Saving the Planet Begins at Breakfast
# Inserted Never Enough: The Neuroscience and Experience of Addiction
# Inserted Hacking Darwin: Genetic Engineering and the Future of Humanity
# Inserted Indistractable: How to Control Your Attention and Choose Your Life
# Inserted Burnout: The Secret to Unlocking the Stress Cycle
# Inserted Because Internet: Understanding the New Rules of Language
# Inserted Lifespan: Why We Age—and Why We Don't Have To
# Inserted The Perfect Predator: A Scientist's Race to Save Her Husband from a Deadly Superbug: A Memoir
# Inserted Super Pumped: The Battle for Uber
# Inserted Something Deeply Hidden: Quantum Worlds and the Emergence of Spacetime
# Inserted Blueprint: The Evolutionary Origins of a Good Society
# food-cookbooks
# Inserted Antoni in the Kitchen
# Inserted Antoni in the Kitchen
# Inserted Antoni in the Kitchen
# Inserted The Adventurous Eaters Club: Mastering the Art of Family Mealtime
# Inserted Notes from a Young Black Chef
# Inserted The Little Women Cookbook: Tempting Recipes from the March Sisters and Their Friends and Family
# Inserted Rachael Ray 50: Memories and Meals from a Sweet and Savory Life
# Inserted Plant-Based on a Budget: Delicious Vegan Recipes for Under $30 a Week, for Less Than 30 Minutes a Meal
# Inserted Let's Make Ramen!: A Comic Book Cookbook
# Inserted Save Me the Plums: My Gourmet Memoir
# Inserted Indian-ish: Recipes and Antics from a Modern American Family
# Inserted Happiness Is Baking: Cakes, Pies, Tarts, Muffins, Brownies, Cookies: Favorite Desserts from the Queen of Cake
# Inserted Forking Good: A Cookbook Inspired by The Good Place
# Inserted The Clean Plate: Eat, Reset, Heal
# Inserted Zaitoun: Recipes from the Palestinian Kitchen
# Inserted No Crumbs Left: Whole30 Endorsed, Recipes for Everyday Food Made Marvelous
# Inserted Sunny-Side Up: More Than 100 Breakfast & Brunch Recipes from the Essential Egg to the Perfect Pastry
# Inserted Binging with Babish: 100 Recipes Recreated from Your Favorite Movies and TV Shows
# Inserted Midnight Chicken: & Other Recipes Worth Living For
# Inserted Nothing Fancy
# Inserted Mostly Plants: 101 Delicious Flexitarian Recipes from the Pollan Family
# Inserted Burn the Place: A Memoir
# graphic-novels-comics
# Inserted Pumpkinheads
# Inserted Pumpkinheads
# Inserted Pumpkinheads
# Inserted Heartstopper: Volume Two
# Inserted The Handmaid's Tale: The Graphic Novel
# Inserted They Called Us Enemy
# Inserted Book Love
# Inserted Teen Titans: Raven
# Inserted Shades of Magic Vol. 1: The Steel Prince
# Inserted The Umbrella Academy, Vol. 3: Hotel Oblivion
# Inserted Mooncakes
# Inserted Paper Girls, Vol. 5
# Inserted Kid Gloves: Nine Months of Careful Chaos
# Inserted Bloom
# Inserted Laura Dean Keeps Breaking Up with Me
# Inserted Good Talk: A Memoir in Conversations
# Inserted Under the Moon: A Catwoman Tale
# Inserted The Adventure Zone: Murder on the Rockport Limited!
# Inserted Monstress, Vol. 4: The Chosen
# Inserted Fence, Vol. 3
# Inserted "Okay"
# Inserted Die, Vol. 1: Fantasy Heartbreaker
# poetry-books
# Inserted SHOUT
# Inserted SHOUT
# Inserted SHOUT
# Inserted The Mermaid's Voice Returns in This One
# Inserted The Truth About Magic
# Inserted Lord of the Butterflies
# Inserted Great Goddesses: Life Lessons from Myths and Monsters
# Inserted Love Looks Pretty on You
# Inserted A Bound Woman Is a Dangerous Thing: The Incarceration of African American Women from Harriet Tubman to Sandra Bland
# Inserted When You Ask Me Where I'm Going
# Inserted Empty Bottles Full of Stories
# Inserted Life of the Party
# Inserted Magical Negro
# Inserted Almost Home: Poems
# Inserted The Tradition
# Inserted Deaf Republic: Poems
# Inserted Soft Science
# Inserted I'm Not Your Paper Princess: Poems
# Inserted The Octopus Museum: Poems
# Inserted Aphrodite Made Me Do It
# Inserted A Fortune for Your Disaster
# Inserted The Girl Aquarium
# [{'title': 'Red, White & Royal Blue',
#   'author': 'Casey McQuiston',
#   'rating': 4.38,
#   'pages': '421',
#   'publisher': "St. Martin's Griffin",
#   'ISBN': 'English',
#   'genre': 'Romance',
#   'series': 0,
#   'author_followers': 3680,
#   'publish_date': datetime.datetime(2019, 5, 14, 0, 0)},
#  {'title': 'Red, White & Royal Blue',
#   'author': 'Casey McQuiston',
#   'rating': 4.38,
#   'pages': '421',
#   'publisher': "St. Martin's Griffin",
#   'ISBN': 'English',
#   'genre': 'Romance',
#   'series': 0,
#   'author_followers': 3680,
#   'publish_date': datetime.datetime(2019, 5, 14, 0, 0)},
#  {'title': 'Red, White & Royal Blue',
#   'author': 'Casey McQuiston',
#   'rating': 4.38,
#   'pages': '421',
#   'publisher': "St. Martin's Griffin",
#   'ISBN': 'English',
#   'genre': 'Romance',
#   'series': 0,
#   'author_followers': 3680,
#   'publish_date': datetime.datetime(2019, 5, 14, 0, 0)},
#  {'title': 'The Silent Patient',
#   'author': 'Alex Michaelides',
#   'rating': 4.05,
#   'pages': '323',
#   'publisher': 'Celadon Books',
#   'ISBN': '1250301696',
#   'genre': 'Mystery',
#   'series': 0,
#   'author_followers': 3630,
#   'publish_date': datetime.datetime(2019, 2, 5, 0, 0)},
#  {'title': 'My Sister, the Serial Killer',
#   'author': 'Oyinkan Braithwaite',
#   'rating': 3.78,
#   'pages': '226',
#   'publisher': 'Doubleday Books',
#   'ISBN': '0385544235',
#   'genre': 'Fiction',
#   'series': 0,
#   'author_followers': 1409,
#   'publish_date': datetime.datetime(2018, 11, 20, 0, 0)},
#  {'title': 'The Ten Thousand Doors of January',
#   'author': 'Alix E. Harrow',
#   'rating': 4.15,
#   'pages': '374',
#   'publisher': 'Redhook',
#   'ISBN': '0316421995',
#   'genre': 'Fantasy',
#   'series': 0,
#   'author_followers': 840,
#   'publish_date': datetime.datetime(2019, 9, 10, 0, 0)},
#  {'title': 'The Water Dancer',
#   'author': 'Ta-Nehisi Coates',
#   'rating': 4.15,
#   'pages': '403',
#   'publisher': 'One World',
#   'ISBN': '0399590595',
#   'genre': 'Historical',
#   'series': 0,
#   'author_followers': 8415,
#   'publish_date': datetime.datetime(2019, 9, 24, 0, 0)},
#  {'title': 'Evvie Drake Starts Over',
#   'author': 'Linda  Holmes',
#   'rating': 3.92,
#   'pages': '289',
#   'publisher': 'Ballantine Books',
#   'ISBN': '0525619240',
#   'genre': 'Fiction',
#   'series': 0,
#   'author_followers': 892,
#   'publish_date': datetime.datetime(2019, 6, 25, 0, 0)},
#  {'title': "On Earth We're Briefly Gorgeous",
#   'author': 'Ocean Vuong',
#   'rating': 4.12,
#   'pages': '246',
#   'publisher': 'Penguin Press',
#   'ISBN': '0525562028',
#   'genre': 'Fiction',
#   'series': 0,
#   'author_followers': 1361,
#   'publish_date': datetime.datetime(2019, 6, 4, 0, 0)},
#  {'title': 'A Woman Is No Man',
#   'author': 'Etaf Rum',
#   'rating': 4.24,
#   'pages': '336',
#   'publisher': 'Harper',
#   'ISBN': '0062699768',
#   'genre': 'Fiction',
#   'series': 0,
#   'author_followers': 1030,
#   'publish_date': datetime.datetime(2019, 3, 5, 0, 0)},
#  {'title': 'The Secrets We Kept',
#   'author': 'Lara Prescott',
#   'rating': 3.75,
#   'pages': '349',
#   'publisher': 'Knopf Publishing Group',
#   'ISBN': '0525656154',
#   'genre': 'Historical',
#   'series': 0,
#   'author_followers': 457,
#   'publish_date': datetime.datetime(2019, 9, 3, 0, 0)},
#  {'title': 'Queenie',
#   'author': 'Candice Carty-Williams',
#   'rating': 3.74,
#   'pages': '330',
#   'publisher': 'Gallery/Scout Press',
#   'ISBN': '1501196014',
#   'genre': 'Fiction',
#   'series': 0,
#   'author_followers': 991,
#   'publish_date': datetime.datetime(2019, 3, 19, 0, 0)},
#  {'title': 'Serpent & Dove',
#   'author': 'Shelby Mahurin',
#   'rating': 4.25,
#   'pages': '513',
#   'publisher': 'HarperTeen',
#   'ISBN': 'English',
#   'genre': 'Fantasy',
#   'series': 0,
#   'author_followers': 1436,
#   'publish_date': datetime.datetime(2019, 9, 3, 0, 0)},
#  {'title': 'Miracle Creek',
#   'author': 'Angie  Kim',
#   'rating': 3.95,
#   'pages': '355',
#   'publisher': 'Sarah Crichton Books',
#   'ISBN': '0374156026',
#   'genre': 'Mystery',
#   'series': 0,
#   'author_followers': 996,
#   'publish_date': datetime.datetime(2019, 4, 16, 0, 0)},
#  {'title': 'The Most Fun We Ever Had',
#   'author': 'Claire Lombardo',
#   'rating': 4.07,
#   'pages': '532',
#   'publisher': 'Doubleday Books',
#   'ISBN': '0385544251',
#   'genre': 'Fiction',
#   'series': 0,
#   'author_followers': 653,
#   'publish_date': datetime.datetime(2019, 6, 25, 0, 0)},
#  {'title': 'Boy Swallows Universe',
#   'author': 'Trent Dalton',
#   'rating': 4.45,
#   'pages': '453',
#   'publisher': 'Harper',
#   'ISBN': '0062898108',
#   'genre': 'Fiction',
#   'series': 0,
#   'author_followers': 479,
#   'publish_date': datetime.datetime(2019, 4, 2, 0, 0)},
#  {'title': 'When All Is Said',
#   'author': 'Anne  Griffin',
#   'rating': 4.08,
#   'pages': '326',
#   'publisher': 'Thomas Dunne Books(first published January 24th 2019)',
#   'ISBN': '125020058X',
#   'genre': 'Fiction',
#   'series': 0,
#   'author_followers': 458,
#   'publish_date': datetime.datetime(2019, 3, 5, 0, 0)},
#  {'title': 'House of Salt and Sorrows',
#   'author': 'Erin A. Craig',
#   'rating': 3.98,
#   'pages': '416',
#   'publisher': 'Delacorte',
#   'ISBN': '1984831925',
#   'genre': 'Fantasy',
#   'series': 0,
#   'author_followers': 823,
#   'publish_date': datetime.datetime(2019, 8, 6, 0, 0)},
#  {'title': 'We Hunt the Flame',
#   'author': 'Hafsah Faizal',
#   'rating': 3.83,
#   'pages': '472',
#   'publisher': 'Farrar, Straus and Giroux',
#   'ISBN': '0374311544',
#   'genre': 'Fantasy',
#   'series': 1,
#   'author_followers': 1557,
#   'publish_date': datetime.datetime(2019, 5, 14, 0, 0)},
#  {'title': 'Gideon the Ninth',
#   'author': 'Tamsyn Muir',
#   'rating': 4.27,
#   'pages': '448',
#   'publisher': 'Tor.com',
#   'ISBN': '1250313198',
#   'genre': 'Fantasy',
#   'series': 1,
#   'author_followers': 821,
#   'publish_date': datetime.datetime(2019, 9, 10, 0, 0)},
#  {'title': 'The Friend Zone',
#   'author': 'Abby Jimenez',
#   'rating': 3.96,
#   'pages': '384',
#   'publisher': 'Forever',
#   'ISBN': '1538715600',
#   'genre': 'Romance',
#   'series': 0,
#   'author_followers': 1291,
#   'publish_date': datetime.datetime(2019, 6, 11, 0, 0)},
#  {'title': 'Fleishman Is in Trouble',
#   'author': 'Taffy Brodesser-Akner',
#   'rating': 3.77,
#   'pages': '384',
#   'publisher': 'Random House',
#   'ISBN': '0525510877',
#   'genre': 'Fiction',
#   'series': 0,
#   'author_followers': 494,
#   'publish_date': datetime.datetime(2019, 6, 18, 0, 0)},
#  {'title': 'Five Feet Apart',
#   'author': 'Rachael Lippincott',
#   'rating': 4.18,
#   'pages': '288',
#   'publisher': 'Simon  Schuster Books for Young Readers',
#   'ISBN': '1534437339',
#   'genre': 'Young',
#   'series': 0,
#   'author_followers': 575,
#   'publish_date': datetime.datetime(2018, 11, 20, 0, 0)},
#  {'title': 'Five Feet Apart',
#   'author': 'Rachael Lippincott',
#   'rating': 4.18,
#   'pages': '288',
#   'publisher': 'Simon  Schuster Books for Young Readers',
#   'ISBN': '1534437339',
#   'genre': 'Young',
#   'series': 0,
#   'author_followers': 575,
#   'publish_date': datetime.datetime(2018, 11, 20, 0, 0)},
#  {'title': 'Five Feet Apart',
#   'author': 'Rachael Lippincott',
#   'rating': 4.18,
#   'pages': '288',
#   'publisher': 'Simon  Schuster Books for Young Readers',
#   'ISBN': '1534437339',
#   'genre': 'Young',
#   'series': 0,
#   'author_followers': 575,
#   'publish_date': datetime.datetime(2018, 11, 20, 0, 0)},
#  {'title': 'On the Come Up',
#   'author': 'Angie Thomas',
#   'rating': 4.31,
#   'pages': '447',
#   'publisher': 'Balzer + Bray',
#   'ISBN': '0062498568',
#   'genre': 'Young',
#   'series': 0,
#   'author_followers': 11980,
#   'publish_date': datetime.datetime(2019, 2, 5, 0, 0)},
#  {'title': 'With the Fire on High',
#   'author': 'Elizabeth Acevedo',
#   'rating': 4.29,
#   'pages': '392',
#   'publisher': 'HarperTeen',
#   'ISBN': '006266283X',
#   'genre': 'Young',
#   'series': 0,
#   'author_followers': 2754,
#   'publish_date': datetime.datetime(2019, 5, 7, 0, 0)},
#  {'title': 'Two Can Keep a Secret',
#   'author': 'Karen M. McManus',
#   'rating': 3.97,
#   'pages': '329',
#   'publisher': 'Delacorte Press',
#   'ISBN': '1524714720',
#   'genre': 'Mystery',
#   'series': 0,
#   'author_followers': 5021,
#   'publish_date': datetime.datetime(2019, 1, 8, 0, 0)},
#  {'title': 'The Fountains of Silence',
#   'author': 'Ruta Sepetys',
#   'rating': 4.32,
#   'pages': '512',
#   'publisher': 'Philomel Books',
#   'ISBN': '0399160310',
#   'genre': 'Historical',
#   'series': 0,
#   'author_followers': 11305,
#   'publish_date': datetime.datetime(2019, 10, 1, 0, 0)},
#  {'title': 'Again, but Better',
#   'author': 'Christine Riccio',
#   'rating': 3.69,
#   'pages': '373',
#   'publisher': 'Wednesday Books',
#   'ISBN': '125029925X',
#   'genre': 'comments',
#   'series': 0,
#   'author_followers': 100452,
#   'publish_date': datetime.datetime(2019, 5, 7, 0, 0)},
#  {'title': 'I Wish You All the Best',
#   'author': 'Mason Deaver',
#   'rating': 4.18,
#   'pages': '329',
#   'publisher': 'Push',
#   'ISBN': 'Raleigh, North Carolina',
#   'genre': 'Young',
#   'series': 0,
#   'author_followers': 679,
#   'publish_date': datetime.datetime(2019, 5, 14, 0, 0)},
#  {'title': 'The Vanishing Stair',
#   'author': 'Maureen Johnson',
#   'rating': 4.27,
#   'pages': '384',
#   'publisher': 'Katherine Tegen Books',
#   'ISBN': 'English',
#   'genre': 'Mystery',
#   'series': 0,
#   'author_followers': 9808,
#   'publish_date': datetime.datetime(2019, 1, 22, 0, 0)},
#  {'title': 'American Royals',
#   'author': 'Katharine McGee',
#   'rating': 3.85,
#   'pages': '448',
#   'publisher': 'Random House Books for Young Readers',
#   'ISBN': '1984830171',
#   'genre': 'Young',
#   'series': 1,
#   'author_followers': 1898,
#   'publish_date': datetime.datetime(2019, 9, 3, 0, 0)},
#  {'title': 'The Rest of the Story',
#   'author': 'Sarah Dessen',
#   'rating': 4.1,
#   'pages': '440',
#   'publisher': 'Balzer + Bray',
#   'ISBN': 'English',
#   'genre': 'Young',
#   'series': 0,
#   'author_followers': 41340,
#   'publish_date': datetime.datetime(2019, 6, 4, 0, 0)},
#  {'title': 'Capturing the Devil',
#   'author': 'Kerri Maniscalco',
#   'rating': 4.34,
#   'pages': '453',
#   'publisher': 'JIMMY Patterson',
#   'ISBN': 'English',
#   'genre': 'Historical',
#   'series': 0,
#   'author_followers': 6246,
#   'publish_date': datetime.datetime(2019, 9, 10, 0, 0)},
#  {'title': 'Internment',
#   'author': 'Samira Ahmed',
#   'rating': 3.94,
#   'pages': '387',
#   'publisher': 'Little, Brown Books for Young Readers(first published March 18th 2019)',
#   'ISBN': 'English',
#   'genre': 'Young',
#   'series': 0,
#   'author_followers': 713,
#   'publish_date': datetime.datetime(2019, 3, 19, 0, 0)},
#  {'title': 'The Princess and the Fangirl',
#   'author': 'Ashley Poston',
#   'rating': 3.91,
#   'pages': '320',
#   'publisher': 'Quirk Books',
#   'ISBN': '1683690966',
#   'genre': 'Contemporary',
#   'series': 1,
#   'author_followers': 2346,
#   'publish_date': datetime.datetime(2019, 4, 2, 0, 0)},
#  {'title': 'Frankly in Love',
#   'author': 'David   Yoon',
#   'rating': 3.89,
#   'pages': '432',
#   'publisher': 'G.P. Putnam’s Sons Books for Young Readers',
#   'ISBN': '1984812203',
#   'genre': 'Young',
#   'series': 1,
#   'author_followers': 170,
#   'publish_date': datetime.datetime(2019, 9, 10, 0, 0)},
#  {'title': 'Serious Moonlight',
#   'author': 'Jenn Bennett',
#   'rating': 3.79,
#   'pages': '426',
#   'publisher': 'Simon Pulse',
#   'ISBN': '1534425144',
#   'genre': 'Contemporary',
#   'series': 0,
#   'author_followers': 2846,
#   'publish_date': datetime.datetime(2019, 4, 16, 0, 0)},
#  {'title': 'Opposite of Always',
#   'author': 'Justin A. Reynolds',
#   'rating': 3.76,
#   'pages': '457',
#   'publisher': 'Katherine Tegen Books',
#   'ISBN': '//<![CDATA[\n      var newTip = new Tip',
#   'genre': 'Add',
#   'series': 0,
#   'author_followers': 470,
#   'publish_date': datetime.datetime(2019, 3, 5, 0, 0)},
#  {'title': 'The Grace Year',
#   'author': 'Kim Liggett',
#   'rating': 4.16,
#   'pages': '416',
#   'publisher': 'Wednesday Books',
#   'ISBN': '1250145449',
#   'genre': 'Young',
#   'series': 0,
#   'author_followers': 664,
#   'publish_date': datetime.datetime(2019, 10, 8, 0, 0)},
#  {'title': 'Lovely War',
#   'author': 'Julie Berry',
#   'rating': 4.28,
#   'pages': '480',
#   'publisher': 'Viking Books for Young Readers',
#   'ISBN': '0451469933',
#   'genre': 'Historical',
#   'series': 0,
#   'author_followers': 1212,
#   'publish_date': datetime.datetime(2019, 3, 5, 0, 0)},
#  {'title': 'Love From A to Z',
#   'author': 'S.K. Ali',
#   'rating': 4.13,
#   'pages': '384',
#   'publisher': 'Salaam Reads',
#   'ISBN': 'B07M5V9VS9',
#   'genre': 'Add',
#   'series': 0,
#   'author_followers': 602,
#   'publish_date': datetime.datetime(2019, 4, 30, 0, 0)},
#  {'title': 'Birthday',
#   'author': 'Meredith Russo',
#   'rating': 4.3,
#   'pages': '288',
#   'publisher': 'Flatiron Books',
#   'ISBN': '1250129834',
#   'genre': 'Young',
#   'series': 0,
#   'author_followers': 1108,
#   'publish_date': datetime.datetime(2019, 5, 21, 0, 0)},
#  {'title': 'The Wicked King',
#   'author': 'Holly Black',
#   'rating': 4.46,
#   'pages': '326',
#   'publisher': 'Hot Key Books',
#   'ISBN': '0316310352',
#   'genre': 'Fantasy',
#   'series': 1,
#   'author_followers': 31572,
#   'publish_date': datetime.datetime(2019, 1, 8, 0, 0)},
#  {'title': 'The Wicked King',
#   'author': 'Holly Black',
#   'rating': 4.46,
#   'pages': '326',
#   'publisher': 'Hot Key Books',
#   'ISBN': '0316310352',
#   'genre': 'Fantasy',
#   'series': 1,
#   'author_followers': 31572,
#   'publish_date': datetime.datetime(2019, 1, 8, 0, 0)},
#  {'title': 'The Wicked King',
#   'author': 'Holly Black',
#   'rating': 4.46,
#   'pages': '326',
#   'publisher': 'Hot Key Books',
#   'ISBN': '0316310352',
#   'genre': 'Fantasy',
#   'series': 1,
#   'author_followers': 31572,
#   'publish_date': datetime.datetime(2019, 1, 8, 0, 0)},
#  {'title': 'Wayward Son',
#   'author': 'Rainbow Rowell',
#   'rating': 4.14,
#   'pages': '356',
#   'publisher': 'Wednesday Books',
#   'ISBN': '1250146070',
#   'genre': 'Fantasy',
#   'series': 1,
#   'author_followers': 126816,
#   'publish_date': datetime.datetime(2019, 9, 24, 0, 0)},
#  {'title': 'Queen of Air and Darkness',
#   'author': 'Cassandra Clare',
#   'rating': 4.37,
#   'pages': '893',
#   'publisher': 'Margaret K. McElderry Books',
#   'ISBN': '1442468432',
#   'genre': 'Fantasy',
#   'series': 1,
#   'author_followers': 194944,
#   'publish_date': datetime.datetime(2018, 12, 4, 0, 0)},
#  {'title': 'King of Scars',
#   'author': 'Leigh Bardugo',
#   'rating': 4.22,
#   'pages': '514',
#   'publisher': 'Imprint',
#   'ISBN': '1250142288',
#   'genre': 'Fantasy',
#   'series': 1,
#   'author_followers': 54175,
#   'publish_date': datetime.datetime(2019, 1, 29, 0, 0)},
#  {'title': 'Wilder Girls',
#   'author': 'Rory Power',
#   'rating': 3.63,
#   'pages': '353',
#   'publisher': 'Delacorte Press',
#   'ISBN': '0525645586',
#   'genre': 'Young',
#   'series': 0,
#   'author_followers': 772,
#   'publish_date': datetime.datetime(2019, 7, 9, 0, 0)},
#  {'title': 'The Toll',
#   'author': 'Neal Shusterman',
#   'rating': 4.36,
#   'pages': '627',
#   'publisher': 'Simon & Schuster Books for Young Readers',
#   'ISBN': 'English',
#   'genre': 'Young',
#   'series': 0,
#   'author_followers': 15292,
#   'publish_date': datetime.datetime(2019, 11, 5, 0, 0)},
#  {'title': 'A Curse So Dark and Lonely',
#   'author': 'Brigid Kemmerer',
#   'rating': 4.23,
#   'pages': '484',
#   'publisher': 'Bloomsbury YA',
#   'ISBN': '1681195089',
#   'genre': 'Fantasy',
#   'series': 1,
#   'author_followers': 6035,
#   'publish_date': datetime.datetime(2019, 1, 29, 0, 0)},
#  {'title': 'Finale',
#   'author': 'Stephanie Garber',
#   'rating': 4.2,
#   'pages': '478',
#   'publisher': 'Flatiron Books',
#   'ISBN': '1250157668',
#   'genre': 'Fantasy',
#   'series': 1,
#   'author_followers': 9756,
#   'publish_date': datetime.datetime(2019, 5, 7, 0, 0)},
#  {'title': 'Sorcery of Thorns',
#   'author': 'Margaret  Rogerson',
#   'rating': 4.17,
#   'pages': '456',
#   'publisher': 'Margaret K. McElderry Books',
#   'ISBN': '1481497618',
#   'genre': 'Fantasy',
#   'series': 0,
#   'author_followers': 3703,
#   'publish_date': datetime.datetime(2019, 6, 4, 0, 0)},
#  {'title': 'Aurora Rising',
#   'author': 'Amie Kaufman',
#   'rating': 4.18,
#   'pages': '473',
#   'publisher': 'Knopf Books for Young Readers(first published May 6th 2019)',
#   'ISBN': 'English',
#   'genre': 'Science',
#   'series': 0,
#   'author_followers': 8806,
#   'publish_date': datetime.datetime(2019, 5, 7, 0, 0)},
#  {'title': 'Supernova',
#   'author': 'Marissa Meyer',
#   'rating': 4.51,
#   'pages': '552',
#   'publisher': 'Feiwel & Friends',
#   'ISBN': '1250078385',
#   'genre': 'Fantasy',
#   'series': 1,
#   'author_followers': 82690,
#   'publish_date': datetime.datetime(2019, 11, 5, 0, 0)},
#  {'title': 'Defy Me',
#   'author': 'Tahereh Mafi',
#   'rating': 4.2,
#   'pages': '352',
#   'publisher': 'HarperTeen',
#   'ISBN': 'English',
#   'genre': 'Young',
#   'series': 0,
#   'author_followers': 26331,
#   'publish_date': datetime.datetime(2019, 4, 2, 0, 0)},
#  {'title': 'Bloodwitch',
#   'author': 'Susan Dennard',
#   'rating': 4.33,
#   'pages': '464',
#   'publisher': 'Tor Teen',
#   'ISBN': '0765379325',
#   'genre': 'Fantasy',
#   'series': 1,
#   'author_followers': 7212,
#   'publish_date': datetime.datetime(2019, 2, 12, 0, 0)},
#  {'title': 'Call Down the Hawk',
#   'author': 'Maggie Stiefvater',
#   'rating': 4.51,
#   'pages': '472',
#   'publisher': 'Scholastic Press',
#   'ISBN': '1338188321',
#   'genre': 'Fantasy',
#   'series': 1,
#   'author_followers': 129698,
#   'publish_date': datetime.datetime(2019, 11, 5, 0, 0)},
#  {'title': 'Four Dead Queens',
#   'author': 'Astrid Scholte',
#   'rating': 3.76,
#   'pages': '413',
#   'publisher': "G.P. Putnam's Sons Books for Young Readers",
#   'ISBN': '0525513922',
#   'genre': 'Fantasy',
#   'series': 0,
#   'author_followers': 914,
#   'publish_date': datetime.datetime(2019, 2, 26, 0, 0)},
#  {'title': 'Rebel',
#   'author': 'Marie Lu',
#   'rating': 4.2,
#   'pages': '384',
#   'publisher': 'Roaring Book Press',
#   'ISBN': 'English',
#   'genre': 'Young',
#   'series': 0,
#   'author_followers': 104074,
#   'publish_date': datetime.datetime(2019, 10, 1, 0, 0)},
#  {'title': 'The Secret Commonwealth',
#   'author': 'Philip Pullman',
#   'rating': 4.19,
#   'pages': '633',
#   'publisher': 'Alfred A. Knopf Books for Young Readers',
#   'ISBN': '0553510665',
#   'genre': 'Add',
#   'series': 1,
#   'author_followers': 17468,
#   'publish_date': datetime.datetime(2019, 10, 3, 0, 0)},
#  {'title': 'Serpent & Dove',
#   'author': 'Shelby Mahurin',
#   'rating': 4.25,
#   'pages': '513',
#   'publisher': 'HarperTeen',
#   'ISBN': 'English',
#   'genre': 'Fantasy',
#   'series': 0,
#   'author_followers': 1436,
#   'publish_date': datetime.datetime(2019, 9, 3, 0, 0)},
#  {'title': 'We Hunt the Flame',
#   'author': 'Hafsah Faizal',
#   'rating': 3.83,
#   'pages': '472',
#   'publisher': 'Farrar, Straus and Giroux',
#   'ISBN': '0374311544',
#   'genre': 'Fantasy',
#   'series': 1,
#   'author_followers': 1557,
#   'publish_date': datetime.datetime(2019, 5, 14, 0, 0)},
#  {'title': 'The Gilded Wolves',
#   'author': 'Roshani Chokshi',
#   'rating': 3.67,
#   'pages': '388',
#   'publisher': 'Wednesday Books',
#   'ISBN': '125014454X',
#   'genre': 'Fantasy',
#   'series': 1,
#   'author_followers': 5377,
#   'publish_date': datetime.datetime(2019, 1, 15, 0, 0)},
#  {'title': "The Tyrant's Tomb",
#   'author': 'Rick Riordan',
#   'rating': 4.44,
#   'pages': '440',
#   'publisher': 'Disney-Hyperion',
#   'ISBN': '1484746449',
#   'genre': 'Fantasy',
#   'series': 1,
#   'author_followers': 279351,
#   'publish_date': datetime.datetime(2019, 9, 24, 0, 0)},
#  {'title': "The Tyrant's Tomb",
#   'author': 'Rick Riordan',
#   'rating': 4.44,
#   'pages': '440',
#   'publisher': 'Disney-Hyperion',
#   'ISBN': '1484746449',
#   'genre': 'Fantasy',
#   'series': 1,
#   'author_followers': 279352,
#   'publish_date': datetime.datetime(2019, 9, 24, 0, 0)},
#  {'title': "The Tyrant's Tomb",
#   'author': 'Rick Riordan',
#   'rating': 4.44,
#   'pages': '440',
#   'publisher': 'Disney-Hyperion',
#   'ISBN': '1484746449',
#   'genre': 'Fantasy',
#   'series': 1,
#   'author_followers': 279352,
#   'publish_date': datetime.datetime(2019, 9, 24, 0, 0)},
#  {'title': 'Tunnel of Bones',
#   'author': 'Victoria Schwab',
#   'rating': 4.15,
#   'pages': '304',
#   'publisher': 'Scholastic Press',
#   'ISBN': '1338111043',
#   'genre': 'Childrens',
#   'series': 1,
#   'author_followers': 49561,
#   'publish_date': datetime.datetime(2019, 9, 3, 0, 0)},
#  {'title': 'Guts',
#   'author': 'Raina Telgemeier',
#   'rating': 4.37,
#   'pages': '213',
#   'publisher': 'Graphix',
#   'ISBN': '0545852501',
#   'genre': 'Sequential',
#   'series': 1,
#   'author_followers': 9050,
#   'publish_date': datetime.datetime(2019, 9, 17, 0, 0)},
#  {'title': 'The Remarkable Journey of Coyote Sunrise',
#   'author': 'Dan Gemeinhart',
#   'rating': 4.53,
#   'pages': '344',
#   'publisher': 'Henry Holt',
#   'ISBN': '//<![CDATA[\n      var newTip = new Tip',
#   'genre': 'Childrens',
#   'series': 0,
#   'author_followers': 740,
#   'publish_date': datetime.datetime(2019, 1, 8, 0, 0)},
#  {'title': 'New Kid',
#   'author': 'Jerry Craft',
#   'rating': 4.06,
#   'pages': '256',
#   'publisher': 'HarperCollins',
#   'ISBN': 'New York City, New York',
#   'genre': 'Sequential',
#   'series': 0,
#   'author_followers': 155,
#   'publish_date': datetime.datetime(2019, 2, 5, 0, 0)},
#  {'title': 'A Crystal of Time',
#   'author': 'Soman Chainani',
#   'rating': 4.53,
#   'pages': '624',
#   'publisher': 'HarperCollins',
#   'ISBN': '0062695177',
#   'genre': 'Fantasy',
#   'series': 1,
#   'author_followers': 3635,
#   'publish_date': datetime.datetime(2019, 3, 5, 0, 0)},
#  {'title': 'Dragon Pearl',
#   'author': 'Yoon Ha Lee',
#   'rating': 3.83,
#   'pages': '312',
#   'publisher': 'Rick Riordan Presents',
#   'ISBN': '136801335X',
#   'genre': 'Fantasy',
#   'series': 0,
#   'author_followers': 1137,
#   'publish_date': datetime.datetime(2019, 1, 15, 0, 0)},
#  {'title': "Diary of an Awesome Friendly Kid: Rowley Jefferson's Journal",
#   'author': 'Jeff Kinney',
#   'rating': 3.98,
#   'pages': '224',
#   'publisher': 'Harry N. Abrams',
#   'ISBN': '141974027X',
#   'genre': 'Humor',
#   'series': 0,
#   'author_followers': 10685,
#   'publish_date': datetime.datetime(2019, 4, 9, 0, 0)},
#  {'title': 'The Strangers',
#   'author': 'Margaret Peterson Haddix',
#   'rating': 3.84,
#   'pages': '416',
#   'publisher': 'Katherine Tegen Books',
#   'ISBN': '0062838377',
#   'genre': 'Childrens',
#   'series': 1,
#   'author_followers': 4973,
#   'publish_date': datetime.datetime(2019, 4, 2, 0, 0)},
#  {'title': 'Aru Shah and the Song of Death',
#   'author': 'Roshani Chokshi',
#   'rating': 4.31,
#   'pages': '381',
#   'publisher': 'Rick Riordan Presents',
#   'ISBN': '1368013848',
#   'genre': 'Fantasy',
#   'series': 0,
#   'author_followers': 5377,
#   'publish_date': datetime.datetime(2019, 4, 30, 0, 0)},
#  {'title': 'The Bridge Home',
#   'author': 'Padma Venkatraman',
#   'rating': 4.34,
#   'pages': '208',
#   'publisher': 'Nancy Paulsen Books',
#   'ISBN': 'English',
#   'genre': 'Childrens',
#   'series': 0,
#   'author_followers': 252,
#   'publish_date': datetime.datetime(2019, 2, 5, 0, 0)},
#  {'title': 'Other Words for Home',
#   'author': 'Jasmine Warga',
#   'rating': 4.47,
#   'pages': '352',
#   'publisher': 'Balzer + Bray',
#   'ISBN': '//<![CDATA[\n      var newTip = new Tip',
#   'genre': 'Childrens',
#   'series': 0,
#   'author_followers': 1344,
#   'publish_date': datetime.datetime(2019, 5, 28, 0, 0)},
#  {'title': 'Legacy',
#   'author': 'Shannon Messenger',
#   'rating': 4.63,
#   'pages': '816',
#   'publisher': 'Aladdin',
#   'ISBN': 'English',
#   'genre': 'Fantasy',
#   'series': 0,
#   'author_followers': 5585,
#   'publish_date': datetime.datetime(2019, 11, 5, 0, 0)},
#  {'title': 'Shouting at the Rain',
#   'author': 'Lynda Mullaly Hunt',
#   'rating': 4.22,
#   'pages': '288',
#   'publisher': 'Nancy Paulsen Books',
#   'ISBN': '//<![CDATA[\n      var newTip = new Tip',
#   'genre': 'Childrens',
#   'series': 0,
#   'author_followers': 866,
#   'publish_date': datetime.datetime(2019, 5, 7, 0, 0)},
#  {'title': 'To Night Owl from Dogfish',
#   'author': 'Holly Goldberg Sloan',
#   'rating': 4.09,
#   'pages': '304',
#   'publisher': 'Dial Books',
#   'ISBN': '0525553231',
#   'genre': 'Childrens',
#   'series': 0,
#   'author_followers': 922,
#   'publish_date': datetime.datetime(2019, 2, 12, 0, 0)},
#  {'title': 'Dead Voices',
#   'author': 'Katherine Arden',
#   'rating': 4.13,
#   'pages': '236',
#   'publisher': "G.P. Putnam's Sons Books for Young Readers",
#   'ISBN': 'English',
#   'genre': 'Childrens',
#   'series': 0,
#   'author_followers': 7563,
#   'publish_date': datetime.datetime(2019, 8, 27, 0, 0)},
#  {'title': 'The Unteachables',
#   'author': 'Gordon Korman',
#   'rating': 4.28,
#   'pages': '288',
#   'publisher': 'Balzer + Bray',
#   'ISBN': '0062563882',
#   'genre': 'Childrens',
#   'series': 0,
#   'author_followers': 2325,
#   'publish_date': datetime.datetime(2019, 1, 8, 0, 0)},
#  {'title': 'A Tale of Magic...',
#   'author': 'Chris Colfer',
#   'rating': 4.38,
#   'pages': '496',
#   'publisher': 'Little, Brown Books for Young Readers',
#   'ISBN': 'A Tale of Magic #1',
#   'genre': 'Fantasy',
#   'series': 0,
#   'author_followers': 7038,
#   'publish_date': datetime.datetime(2019, 10, 1, 0, 0)},
#  {'title': 'Dear Sweet Pea',
#   'author': 'Julie   Murphy',
#   'rating': 4.12,
#   'pages': '273',
#   'publisher': 'Balzer + Bray',
#   'ISBN': '0062473077',
#   'genre': 'Childrens',
#   'series': 0,
#   'author_followers': 3234,
#   'publish_date': datetime.datetime(2019, 10, 1, 0, 0)},
#  {'title': 'Tristan Strong Punches a Hole in the Sky',
#   'author': 'Kwame Mbalia',
#   'rating': 4.41,
#   'pages': '496',
#   'publisher': 'Rick Riordan Presents',
#   'ISBN': '1368039936',
#   'genre': 'Fantasy',
#   'series': 1,
#   'author_followers': 148,
#   'publish_date': datetime.datetime(2019, 10, 15, 0, 0)},
#  {'title': 'A Beautiful Day in the Neighborhood: The Poetry of Mister Rogers',
#   'author': 'Fred Rogers',
#   'rating': 4.4,
#   'pages': '144',
#   'publisher': 'Quirk Books',
#   'ISBN': '168369113X',
#   'genre': 'Poetry',
#   'series': 0,
#   'author_followers': 505,
#   'publish_date': datetime.datetime(2019, 3, 19, 0, 0)},
#  {'title': 'A Beautiful Day in the Neighborhood: The Poetry of Mister Rogers',
#   'author': 'Fred Rogers',
#   'rating': 4.4,
#   'pages': '144',
#   'publisher': 'Quirk Books',
#   'ISBN': '168369113X',
#   'genre': 'Poetry',
#   'series': 0,
#   'author_followers': 505,
#   'publish_date': datetime.datetime(2019, 3, 19, 0, 0)},
#  {'title': 'A Beautiful Day in the Neighborhood: The Poetry of Mister Rogers',
#   'author': 'Fred Rogers',
#   'rating': 4.4,
#   'pages': '144',
#   'publisher': 'Quirk Books',
#   'ISBN': '168369113X',
#   'genre': 'Poetry',
#   'series': 0,
#   'author_followers': 505,
#   'publish_date': datetime.datetime(2019, 3, 19, 0, 0)},
#  {'title': 'Sulwe',
#   'author': 'Lupita Nyong’o',
#   'rating': 4.58,
#   'pages': '48',
#   'publisher': 'Simon  Schuster Books for Young Readers',
#   'ISBN': '1534425365',
#   'genre': 'Childrens',
#   'series': 0,
#   'author_followers': 44,
#   'publish_date': datetime.datetime(2019, 10, 15, 0, 0)},
#  {'title': 'The Good Egg',
#   'author': 'Jory John',
#   'rating': 4.1,
#   'pages': '34',
#   'publisher': 'HarperCollins(first published 2019)',
#   'ISBN': 'English',
#   'genre': 'Childrens',
#   'series': 0,
#   'author_followers': 167,
#   'publish_date': datetime.datetime(2019, 2, 12, 0, 0)},
#  {'title': 'Hair Love',
#   'author': 'Matthew A. Cherry',
#   'rating': 4.5,
#   'pages': '32',
#   'publisher': 'Kokila',
#   'ISBN': '0525553363',
#   'genre': 'Childrens',
#   'series': 0,
#   'author_followers': 8,
#   'publish_date': datetime.datetime(2019, 5, 14, 0, 0)},
#  {'title': 'Unicorn Day',
#   'author': 'Diana  Murray',
#   'rating': 3.76,
#   'pages': '32',
#   'publisher': 'Sourcebooks Jabberwocky',
#   'ISBN': 'English',
#   'genre': 'Childrens',
#   'series': 0,
#   'author_followers': 120,
#   'publish_date': datetime.datetime(2019, 6, 4, 0, 0)},
#  {'title': 'A Tiger Like Me',
#   'author': 'Michael Engler',
#   'rating': 4.1,
#   'pages': '32',
#   'publisher': 'Amazon Crossing Kids',
#   'ISBN': '//<![CDATA[\n      var newTip = new Tip',
#   'genre': 'Childrens',
#   'series': 0,
#   'author_followers': 8,
#   'publish_date': datetime.datetime(2019, 9, 1, 0, 0)},
#  {'title': 'Because',
#   'author': 'Mo Willems',
#   'rating': 4.27,
#   'pages': '40',
#   'publisher': 'Hyperion Books for Children',
#   'ISBN': 'English',
#   'genre': 'Childrens',
#   'series': 0,
#   'author_followers': 3140,
#   'publish_date': datetime.datetime(2019, 3, 5, 0, 0)},
#  {'title': 'We Are (Not) Friends',
#   'author': 'Anna Kang',
#   'rating': 3.85,
#   'pages': '40',
#   'publisher': 'Two Lions',
#   'ISBN': 'English',
#   'genre': 'Childrens',
#   'series': 0,
#   'author_followers': 125,
#   'publish_date': datetime.datetime(2019, 5, 1, 0, 0)},
#  {'title': 'Just Because',
#   'author': 'Mac Barnett',
#   'rating': 3.83,
#   'pages': '40',
#   'publisher': 'Candlewick Press',
#   'ISBN': 'English',
#   'genre': 'Add',
#   'series': 0,
#   'author_followers': 730,
#   'publish_date': datetime.datetime(2019, 9, 10, 0, 0)},
#  {'title': 'A Piglet Named Mercy',
#   'author': 'Kate DiCamillo',
#   'rating': 3.84,
#   'pages': '32',
#   'publisher': 'Candlewick Press',
#   'ISBN': 'English',
#   'genre': 'Childrens',
#   'series': 1,
#   'author_followers': 6167,
#   'publish_date': datetime.datetime(2019, 4, 2, 0, 0)},
#  {'title': "Pirates Don't Go to Kindergarten!",
#   'author': 'Lisa     Robinson',
#   'rating': 4.15,
#   'pages': '32',
#   'publisher': 'Two Lions',
#   'ISBN': '//<![CDATA[\n      var newTip = new Tip',
#   'genre': 'Childrens',
#   'series': 0,
#   'author_followers': 31,
#   'publish_date': datetime.datetime(2019, 8, 1, 0, 0)},
#  {'title': 'The Proudest Blue',
#   'author': 'Ibtihaj Muhammad',
#   'rating': 4.56,
#   'pages': '40',
#   'publisher': 'Little Brown Books',
#   'ISBN': 'English',
#   'genre': 'Childrens',
#   'series': 0,
#   'author_followers': 36,
#   'publish_date': datetime.datetime(2019, 9, 10, 0, 0)},
#  {'title': 'How to Read a Book',
#   'author': 'Kwame Alexander',
#   'rating': 3.79,
#   'pages': '32',
#   'publisher': 'HarperCollins',
#   'ISBN': 'English',
#   'genre': 'Childrens',
#   'series': 0,
#   'author_followers': 1643,
#   'publish_date': datetime.datetime(2019, 6, 18, 0, 0)},
#  {'title': "It's Not Hansel and Gretel",
#   'author': 'Josh Funk',
#   'rating': 4.05,
#   'pages': '40',
#   'publisher': 'Two Lions',
#   'ISBN': "It's Not a Fairy Tale #2",
#   'genre': 'Childrens',
#   'series': 0,
#   'author_followers': 356,
#   'publish_date': datetime.datetime(2019, 3, 1, 0, 0)},
#  {'title': 'Fry Bread: A Native American Family Story',
#   'author': 'Kevin Noble Maillard',
#   'rating': 4.53,
#   'pages': '42',
#   'publisher': 'Roaring Brook Press',
#   'ISBN': '1626727465',
#   'genre': 'Childrens',
#   'series': 0,
#   'author_followers': 7,
#   'publish_date': datetime.datetime(2019, 10, 22, 0, 0)},
#  {'title': 'What If Everybody Thought That?',
#   'author': 'Ellen Javernick',
#   'rating': 3.46,
#   'pages': '32',
#   'publisher': 'Two Lions',
#   'ISBN': 'What If Everybody? #3',
# ...
#   'rating': 3.57,
#   'pages': '288',
#   'publisher': 'Grand Central Publishing',
#   'ISBN': 'English',
#   'genre': 'Food',
#   'series': 0,
#   'author_followers': 234,
#   'publish_date': datetime.datetime(2019, 1, 8, 0, 0)},
#  {'title': 'Zaitoun: Recipes from the Palestinian Kitchen',
#   'author': 'Yasmin    Khan',
#   'rating': 4.4,
#   'pages': '256',
#   'publisher': 'W. W. Norton  Company',
#   'ISBN': '//<![CDATA[\n      var newTip = new Tip',
#   'genre': 'Food',
#   'series': 0,
#   'author_followers': 2,
#   'publish_date': datetime.datetime(2019, 2, 5, 0, 0)},
#  {'title': 'No Crumbs Left: Whole30 Endorsed, Recipes for Everyday Food Made Marvelous',
#   'author': 'Teri Turner',
#   'rating': 4.54,
#   'pages': '304',
#   'publisher': 'Houghton Mifflin Harcourt',
#   'ISBN': '//<![CDATA[\n      var newTip = new Tip',
#   'genre': 'Food',
#   'series': 0,
#   'author_followers': 5,
#   'publish_date': datetime.datetime(2019, 5, 21, 0, 0)},
#  {'title': 'Sunny-Side Up: More Than 100 Breakfast & Brunch Recipes from the Essential Egg to the Perfect Pastry',
#   'author': 'Waylynn Lucas',
#   'rating': 4.05,
#   'pages': '240',
#   'publisher': 'Rodale Book',
#   'ISBN': 'English',
#   'genre': 'Food',
#   'series': 0,
#   'author_followers': 3,
#   'publish_date': datetime.datetime(2019, 8, 27, 0, 0)},
#  {'title': 'Binging with Babish: 100 Recipes Recreated from Your Favorite Movies and TV Shows',
#   'author': 'Andrew Rea',
#   'rating': 4.43,
#   'pages': '336',
#   'publisher': 'Houghton Mifflin Harcourt',
#   'ISBN': '//<![CDATA[\n      var newTip = new Tip',
#   'genre': 'Food',
#   'series': 0,
#   'author_followers': 12,
#   'publish_date': datetime.datetime(2019, 10, 22, 0, 0)},
#  {'title': 'Midnight Chicken: & Other Recipes Worth Living For',
#   'author': 'Ella Risbridger',
#   'rating': 4.46,
#   'pages': '288',
#   'publisher': 'Bloomsbury Publishing',
#   'ISBN': '//<![CDATA[\n      var newTip = new Tip',
#   'genre': 'Food',
#   'series': 0,
#   'author_followers': 11,
#   'publish_date': datetime.datetime(2019, 1, 10, 0, 0)},
#  {'title': 'Nothing Fancy',
#   'author': 'Alison Roman',
#   'rating': 4.41,
#   'pages': '320',
#   'publisher': 'Clarkson Potter Publishers(first published October 1st 2019)',
#   'ISBN': '//<![CDATA[\n      var newTip = new Tip',
#   'genre': 'Food',
#   'series': 0,
#   'author_followers': 21,
#   'publish_date': datetime.datetime(2019, 10, 22, 0, 0)},
#  {'title': 'Mostly Plants: 101 Delicious Flexitarian Recipes from the Pollan Family',
#   'author': 'Tracy Pollan',
#   'rating': 3.86,
#   'pages': '272',
#   'publisher': 'Harper Wave',
#   'ISBN': 'English',
#   'genre': 'Food',
#   'series': 0,
#   'author_followers': 9,
#   'publish_date': datetime.datetime(2019, 4, 16, 0, 0)},
#  {'title': 'Burn the Place: A Memoir',
#   'author': 'Iliana Regan',
#   'rating': 3.83,
#   'pages': '250',
#   'publisher': 'Agate Midway',
#   'ISBN': 'National Book Award Nominee for Nonfiction ',
#   'genre': 'Autobiography',
#   'series': 0,
#   'author_followers': 7,
#   'publish_date': datetime.datetime(2019, 7, 16, 0, 0)},
#  {'title': 'Pumpkinheads',
#   'author': 'Rainbow Rowell',
#   'rating': 4.19,
#   'pages': '209',
#   'publisher': 'First Second',
#   'ISBN': '125031285X',
#   'genre': 'Sequential',
#   'series': 0,
#   'author_followers': 126818,
#   'publish_date': datetime.datetime(2019, 8, 27, 0, 0)},
#  {'title': 'Pumpkinheads',
#   'author': 'Rainbow Rowell',
#   'rating': 4.19,
#   'pages': '209',
#   'publisher': 'First Second',
#   'ISBN': '125031285X',
#   'genre': 'Sequential',
#   'series': 0,
#   'author_followers': 126818,
#   'publish_date': datetime.datetime(2019, 8, 27, 0, 0)},
#  {'title': 'Pumpkinheads',
#   'author': 'Rainbow Rowell',
#   'rating': 4.19,
#   'pages': '209',
#   'publisher': 'First Second',
#   'ISBN': '125031285X',
#   'genre': 'Sequential',
#   'series': 0,
#   'author_followers': 126818,
#   'publish_date': datetime.datetime(2019, 8, 27, 0, 0)},
#  {'title': 'Heartstopper: Volume Two',
#   'author': 'Alice Oseman',
#   'rating': 4.69,
#   'pages': '296',
#   'publisher': "Hodder Children's Books",
#   'ISBN': '1444951408',
#   'genre': 'Sequential',
#   'series': 1,
#   'author_followers': 5816,
#   'publish_date': datetime.datetime(2019, 7, 11, 0, 0)},
#  {'title': "The Handmaid's Tale: The Graphic Novel",
#   'author': 'Margaret Atwood',
#   'rating': 4.24,
#   'pages': '240',
#   'publisher': 'Nan A. Talese/Doubleday',
#   'ISBN': '038553924X',
#   'genre': 'Sequential',
#   'series': 0,
#   'author_followers': 55642,
#   'publish_date': datetime.datetime(2019, 3, 26, 0, 0)},
#  {'title': 'They Called Us Enemy',
#   'author': 'George Takei',
#   'rating': 4.47,
#   'pages': '208',
#   'publisher': 'Top Shelf Productions',
#   'ISBN': 'English',
#   'genre': 'Sequential',
#   'series': 0,
#   'author_followers': 214,
#   'publish_date': datetime.datetime(2019, 7, 16, 0, 0)},
#  {'title': 'Book Love',
#   'author': 'Debbie Tung',
#   'rating': 4.24,
#   'pages': '137',
#   'publisher': 'Andrews McMeel Publishing',
#   'ISBN': '1449494285',
#   'genre': 'Sequential',
#   'series': 0,
#   'author_followers': 568,
#   'publish_date': datetime.datetime(2019, 1, 1, 0, 0)},
#  {'title': 'Teen Titans: Raven',
#   'author': 'Kami Garcia',
#   'rating': 3.96,
#   'pages': None,
#   'publisher': None,
#   'ISBN': 'Teen Titans #1',
#   'genre': 'Sequential',
#   'series': 0,
#   'author_followers': 15208,
#   'publish_date': None},
#  {'title': 'Shades of Magic Vol. 1: The Steel Prince',
#   'author': 'V.E. Schwab',
#   'rating': 3.68,
#   'pages': '112',
#   'publisher': 'Titan Comics',
#   'ISBN': 'English',
#   'genre': 'Sequential',
#   'series': 0,
#   'author_followers': 22621,
#   'publish_date': datetime.datetime(2019, 3, 6, 0, 0)},
#  {'title': 'The Umbrella Academy, Vol. 3: Hotel Oblivion',
#   'author': 'Gerard Way',
#   'rating': 3.71,
#   'pages': '216',
#   'publisher': 'Dark Horse Comics',
#   'ISBN': 'English',
#   'genre': 'Sequential',
#   'series': 0,
#   'author_followers': 2793,
#   'publish_date': datetime.datetime(2019, 9, 17, 0, 0)},
#  {'title': 'Mooncakes',
#   'author': 'Suzanne  Walker',
#   'rating': 3.96,
#   'pages': '256',
#   'publisher': 'Oni Press',
#   'ISBN': '154930304X',
#   'genre': 'Sequential',
#   'series': 0,
#   'author_followers': 50,
#   'publish_date': datetime.datetime(2019, 10, 22, 0, 0)},
#  {'title': 'Paper Girls, Vol. 5',
#   'author': 'Brian K. Vaughan',
#   'rating': 4.22,
#   'pages': '128',
#   'publisher': 'Image Comics',
#   'ISBN': '1534308679',
#   'genre': 'Sequential',
#   'series': 1,
#   'author_followers': 10006,
#   'publish_date': datetime.datetime(2018, 12, 11, 0, 0)},
#  {'title': 'Kid Gloves: Nine Months of Careful Chaos',
#   'author': 'Lucy Knisley',
#   'rating': 4.4,
#   'pages': '247',
#   'publisher': 'First Second',
#   'ISBN': 'English',
#   'genre': 'Sequential',
#   'series': 0,
#   'author_followers': 1346,
#   'publish_date': datetime.datetime(2019, 2, 26, 0, 0)},
#  {'title': 'Bloom',
#   'author': 'Kevin Panetta',
#   'rating': 4.12,
#   'pages': '368',
#   'publisher': 'First Second(first published January 29th 2019)',
#   'ISBN': '//<![CDATA[\n      var newTip = new Tip',
#   'genre': 'Sequential',
#   'series': 0,
#   'author_followers': 81,
#   'publish_date': datetime.datetime(2019, 2, 12, 0, 0)},
#  {'title': 'Laura Dean Keeps Breaking Up with Me',
#   'author': 'Mariko Tamaki',
#   'rating': 4.18,
#   'pages': '304',
#   'publisher': 'First Second Books',
#   'ISBN': None,
#   'genre': 'Sequential',
#   'series': 0,
#   'author_followers': 895,
#   'publish_date': datetime.datetime(2019, 5, 7, 0, 0)},
#  {'title': 'Good Talk: A Memoir in Conversations',
#   'author': 'Mira Jacob',
#   'rating': 4.45,
#   'pages': '400',
#   'publisher': 'One World',
#   'ISBN': '//<![CDATA[\n      var newTip = new Tip',
#   'genre': 'Sequential',
#   'series': 0,
#   'author_followers': 636,
#   'publish_date': datetime.datetime(2019, 3, 26, 0, 0)},
#  {'title': 'Under the Moon: A Catwoman Tale',
#   'author': 'Lauren Myracle',
#   'rating': 3.63,
#   'pages': '205',
#   'publisher': 'DC Ink',
#   'ISBN': 'English',
#   'genre': 'Sequential',
#   'series': 0,
#   'author_followers': 1826,
#   'publish_date': datetime.datetime(2019, 5, 7, 0, 0)},
#  {'title': 'The Adventure Zone: Murder on the Rockport Limited!',
#   'author': 'Clint McElroy',
#   'rating': 4.67,
#   'pages': '240',
#   'publisher': 'First Second',
#   'ISBN': 'The Adventure Zone Graphic Novels #2',
#   'genre': 'Sequential',
#   'series': 0,
#   'author_followers': 397,
#   'publish_date': datetime.datetime(2019, 7, 16, 0, 0)},
#  {'title': 'Monstress, Vol. 4: The Chosen',
#   'author': 'Marjorie M. Liu',
#   'rating': 4.24,
#   'pages': '176',
#   'publisher': 'Image Comics(first published September 25th 2019)',
#   'ISBN': 'English',
#   'genre': 'Sequential',
#   'series': 0,
#   'author_followers': 2817,
#   'publish_date': datetime.datetime(2019, 10, 1, 0, 0)},
#  {'title': 'Fence, Vol. 3',
#   'author': 'C.S. Pacat',
#   'rating': 4.19,
#   'pages': '112',
#   'publisher': 'BOOM! Box',
#   'ISBN': 'English',
#   'genre': 'Sequential',
#   'series': 0,
#   'author_followers': 7281,
#   'publish_date': datetime.datetime(2019, 8, 20, 0, 0)},
#  {'title': '"Okay"',
#   'author': 'Kieron Gillen',
#   'rating': 4.27,
#   'pages': '168',
#   'publisher': 'Image Comics',
#   'ISBN': 'English',
#   'genre': 'Sequential',
#   'series': 0,
#   'author_followers': 1263,
#   'publish_date': datetime.datetime(2019, 10, 8, 0, 0)},
#  {'title': 'Die, Vol. 1: Fantasy Heartbreaker',
#   'author': 'Kieron Gillen',
#   'rating': 4.13,
#   'pages': '184',
#   'publisher': 'Image Comics(first published June 5th 2019)',
#   'ISBN': 'English',
#   'genre': 'Sequential',
#   'series': 0,
#   'author_followers': 1263,
#   'publish_date': datetime.datetime(2019, 6, 11, 0, 0)},
#  {'title': 'SHOUT',
#   'author': 'Laurie Halse Anderson',
#   'rating': 4.36,
#   'pages': '296',
#   'publisher': 'Viking Books',
#   'ISBN': '0670012106',
#   'genre': 'Poetry',
#   'series': 0,
#   'author_followers': 14159,
#   'publish_date': datetime.datetime(2019, 3, 12, 0, 0)},
#  {'title': 'SHOUT',
#   'author': 'Laurie Halse Anderson',
#   'rating': 4.36,
#   'pages': '296',
#   'publisher': 'Viking Books',
#   'ISBN': '0670012106',
#   'genre': 'Poetry',
#   'series': 0,
#   'author_followers': 14159,
#   'publish_date': datetime.datetime(2019, 3, 12, 0, 0)},
#  {'title': 'SHOUT',
#   'author': 'Laurie Halse Anderson',
#   'rating': 4.36,
#   'pages': '296',
#   'publisher': 'Viking Books',
#   'ISBN': '0670012106',
#   'genre': 'Poetry',
#   'series': 0,
#   'author_followers': 14159,
#   'publish_date': datetime.datetime(2019, 3, 12, 0, 0)},
#  {'title': "The Mermaid's Voice Returns in This One",
#   'author': 'Amanda Lovelace',
#   'rating': 3.78,
#   'pages': '208',
#   'publisher': 'Andrews McMeel Publishing',
#   'ISBN': '1449494161',
#   'genre': 'Poetry',
#   'series': 1,
#   'author_followers': 4055,
#   'publish_date': datetime.datetime(2019, 3, 5, 0, 0)},
#  {'title': 'The Truth About Magic',
#   'author': 'Atticus Poetry',
#   'rating': 4.12,
#   'pages': '256',
#   'publisher': "St. Martin's Griffin",
#   'ISBN': 'English',
#   'genre': 'Poetry',
#   'series': 0,
#   'author_followers': 2139,
#   'publish_date': datetime.datetime(2019, 9, 10, 0, 0)},
#  {'title': 'Lord of the Butterflies',
#   'author': 'Andrea Gibson',
#   'rating': 4.54,
#   'pages': '96',
#   'publisher': 'Button Poetry',
#   'ISBN': '1943735425',
#   'genre': 'Poetry',
#   'series': 0,
#   'author_followers': 1413,
#   'publish_date': datetime.datetime(2018, 11, 27, 0, 0)},
#  {'title': 'Great Goddesses: Life Lessons from Myths and Monsters',
#   'author': 'Nikita Gill',
#   'rating': 4.24,
#   'pages': '256',
#   'publisher': 'Ebury Press',
#   'ISBN': '//<![CDATA[\n      var newTip = new Tip',
#   'genre': 'Poetry',
#   'series': 0,
#   'author_followers': 2249,
#   'publish_date': datetime.datetime(2019, 9, 5, 0, 0)},
#  {'title': 'Love Looks Pretty on You',
#   'author': 'Lang Leav',
#   'rating': 3.82,
#   'pages': '224',
#   'publisher': 'Andrews McMeel Publishing',
#   'ISBN': '//<![CDATA[\n      var newTip = new Tip',
#   'genre': 'Poetry',
#   'series': 0,
#   'author_followers': 8978,
#   'publish_date': datetime.datetime(2019, 1, 29, 0, 0)},
#  {'title': 'A Bound Woman Is a Dangerous Thing: The Incarceration of African American Women from Harriet Tubman to Sandra Bland',
#   'author': 'DaMaris B. Hill',
#   'rating': 4.03,
#   'pages': '192',
#   'publisher': 'Bloomsbury Publishing',
#   'ISBN': '//<![CDATA[\n      var newTip = new Tip',
#   'genre': 'Poetry',
#   'series': 0,
#   'author_followers': 35,
#   'publish_date': datetime.datetime(2019, 1, 15, 0, 0)},
#  {'title': "When You Ask Me Where I'm Going",
#   'author': 'Jasmin Kaur',
#   'rating': 4.1,
#   'pages': '256',
#   'publisher': 'HarperCollins',
#   'ISBN': '0062912615',
#   'genre': 'Poetry',
#   'series': 0,
#   'author_followers': 47,
#   'publish_date': datetime.datetime(2019, 10, 1, 0, 0)},
#  {'title': 'Empty Bottles Full of Stories',
#   'author': 'R.H. Sin',
#   'rating': 3.67,
#   'pages': '240',
#   'publisher': 'Andrews McMeel Publishing',
#   'ISBN': '//<![CDATA[\n      var newTip = new Tip',
#   'genre': 'Poetry',
#   'series': 0,
#   'author_followers': 2339,
#   'publish_date': datetime.datetime(2019, 2, 5, 0, 0)},
#  {'title': 'Life of the Party',
#   'author': 'Olivia Gatwood',
#   'rating': 4.37,
#   'pages': '128',
#   'publisher': 'Dial Press(first published August 20th 2019)',
#   'ISBN': '1984801902',
#   'genre': 'Poetry',
#   'series': 0,
#   'author_followers': 261,
#   'publish_date': datetime.datetime(2019, 8, 27, 0, 0)},
#  {'title': 'Magical Negro',
#   'author': 'Morgan  Parker',
#   'rating': 4.31,
#   'pages': '112',
#   'publisher': 'Tin House Books',
#   'ISBN': '1947793187',
#   'genre': 'Poetry',
#   'series': 0,
#   'author_followers': 340,
#   'publish_date': datetime.datetime(2019, 2, 5, 0, 0)},
#  {'title': 'Almost Home: Poems',
#   'author': 'Madisen Kuhn',
#   'rating': 4.6,
#   'pages': '224',
#   'publisher': 'Gallery Books',
#   'ISBN': '//<![CDATA[\n      var newTip = new Tip',
#   'genre': 'Poetry',
#   'series': 0,
#   'author_followers': 380,
#   'publish_date': datetime.datetime(2019, 10, 1, 0, 0)},
#  {'title': 'The Tradition',
#   'author': 'Jericho Brown',
#   'rating': 4.42,
#   'pages': '77',
#   'publisher': 'Copper Canyon Press',
#   'ISBN': 'English',
#   'genre': 'Poetry',
#   'series': 0,
#   'author_followers': 155,
#   'publish_date': datetime.datetime(2019, 4, 2, 0, 0)},
#  {'title': 'Deaf Republic: Poems',
#   'author': 'Ilya Kaminsky',
#   'rating': 4.56,
#   'pages': '80',
#   'publisher': 'Graywolf Press(first published January 1st 2011)',
#   'ISBN': 'National Book Award Finalist for Poetry ',
#   'genre': 'Poetry',
#   'series': 0,
#   'author_followers': 130,
#   'publish_date': datetime.datetime(2019, 3, 5, 0, 0)},
#  {'title': 'Soft Science',
#   'author': 'Franny Choi',
#   'rating': 4.22,
#   'pages': '100',
#   'publisher': 'Alice James Books',
#   'ISBN': '1938584996',
#   'genre': 'Poetry',
#   'series': 0,
#   'author_followers': 123,
#   'publish_date': datetime.datetime(2019, 4, 2, 0, 0)},
#  {'title': "I'm Not Your Paper Princess: Poems",
#   'author': 'J.R. Rogue',
#   'rating': 4.77,
#   'pages': '50',
#   'publisher': 'Independently published',
#   'ISBN': '//<![CDATA[\n      var newTip = new Tip',
#   'genre': 'Poetry',
#   'series': 0,
#   'author_followers': 532,
#   'publish_date': datetime.datetime(2019, 10, 17, 0, 0)},
#  {'title': 'The Octopus Museum: Poems',
#   'author': 'Brenda Shaughnessy',
#   'rating': 3.78,
#   'pages': '96',
#   'publisher': 'Knopf Publishing Group',
#   'ISBN': 'English',
#   'genre': 'Poetry',
#   'series': 0,
#   'author_followers': 93,
#   'publish_date': datetime.datetime(2019, 3, 19, 0, 0)},
#  {'title': 'Aphrodite Made Me Do It',
#   'author': 'Trista Mateer',
#   'rating': 4.15,
#   'pages': '224',
#   'publisher': 'Central Avenue Publishing',
#   'ISBN': '//<![CDATA[\n      var newTip = new Tip',
#   'genre': 'Poetry',
#   'series': 0,
#   'author_followers': 575,
#   'publish_date': datetime.datetime(2019, 10, 1, 0, 0)},
#  {'title': 'A Fortune for Your Disaster',
#   'author': 'Hanif Abdurraqib',
#   'rating': 4.45,
#   'pages': '120',
#   'publisher': 'Tin House Books',
#   'ISBN': '1947793438',
#   'genre': 'Poetry',
#   'series': 0,
#   'author_followers': 641,
#   'publish_date': datetime.datetime(2019, 9, 3, 0, 0)},
#  {'title': 'The Girl Aquarium',
#   'author': 'Jen Campbell',
#   'rating': 3.88,
#   'pages': '71',
#   'publisher': 'Bloodaxe Books(first published April 25th 2019)',
#   'ISBN': '1780374496',
#   'genre': 'Poetry',
#   'series': 0,
#   'author_followers': 9942,
#   'publish_date': datetime.datetime(2019, 7, 17, 0, 0)}]

# %%
len(books_2019)
# Out:
# 440

# %%
def get_ISBN(page):
    try:
        return page.find_all(class_='infoBoxRowItem')[1].get_text(strip=True).split('(')[0]
    except:
        return None

# %%
def get_title(page):
    try:
        return page.find(id = 'bookTitle').get_text(strip=True)
    except:
        return None

# %%
def get_author(page):
    try:
        return page.find('span', itemprop = 'name').get_text(strip=True)
    except:
        return None

# %%
def get_rating(page):
    try:
        return float(page.find('span', itemprop = 'ratingValue').get_text(strip=True))
    except:
        return None

# %%
def get_pages(page):
    try:
        return page.find('span', itemprop = 'numberOfPages').get_text(strip=True).split(' ')[0]
    except:
        return None

# %%
def get_publisher(page):
    try:
        details = page.find_all('div', 'row')
        row = details[1].get_text(strip=True)
        publisher = row.split('by')[1].strip()
        return publisher
    except:
        return None

# %%
def get_genre(page):
    try:
        genre = page.find_all('div', class_='elementList')[0].get_text(strip=True)
        genre = re.findall('(\w+[a-zA-Z])', genre)[0]
        return genre
    except: 
        return None

# %%
import re
def solve(s):                                             
    return re.sub(r'(\d)(st|nd|rd|th)', r'\1', s)

# %%
import datetime

# %%
def get_release_date(page):
    try:
        details = page.find_all('div', 'row')
        row = details[1].get_text(strip=True)
        row1 = row.split('Published')[1].strip()
        date = row1.split('by')[0].strip()
        date = datetime.datetime.strptime(solve(date), "%B %d %Y")
        return date
    except:
        return None

# %%
def get_series(page):
    try:
        if page.find_all('div', class_='infoBoxRowTitle')[3].get_text() == 'Series':
            return 1
        else:
            return 0
    except:
        return 0

# %%
def get_followers(page):
    try:
        bio = page.find('div', class_ = 'bookAuthorProfile')
        parse = bio.get_text(strip=True)
        parse1 = re.findall('(\d+(?:[\.,]\d+)?)',parse)[0]
        final = parse1.replace(',', '')
        return int(final)
    except:
        return None

# %% [markdown]
# ## Webscrape celebrity bookclubs

# %%
import urllib.request

# %% [markdown]
# ### Reese Witherspoon bookclub

# %%
reesebooks=[]

url = 'https://www.barnesandnoble.com/b/books/book-club-selections/reese-witherspoons-book-club/_/N-29Z8q8Z2qxw?Nrpp=40&page=1'
resp = urllib.request.urlopen(url)
soup = BS(resp, from_encoding=resp.info().get_param('charset'))
for info in soup.find_all(class_='product-shelf-title product-info-title pt-xs'):
    book = info.get_text(strip=True)
    reesebooks.append(book)

# %%
reesebooks
# Out:
# ['Where the Crawdads Sing',
#  'The Giver of Stars',
#  'Conviction',
#  'The Alice Network',
#  'Little Fires Everywhere',
#  'Eleanor Oliphant Is Completely…',
#  'Where the Crawdads Sing Deluxe…',
#  'One Day in December',
#  'The Lying Game',
#  'Daisy Jones & The Six',
#  'The Library Book',
#  'The Last Mrs. Parrish',
#  'The Rules of Magic',
#  'The Secrets We Kept',
#  'The Light We Lost',
#  'The Last House Guest',
#  'Whisper Network',
#  'Next Year in Havana',
#  'The Cactus',
#  'The Other Woman',
#  'Something in the Water',
#  'This Is How It Always Is: A…',
#  'Braving the Wilderness: The…',
#  'The Night Tiger',
#  'The Proposal',
#  'Fair Play: A Game-Changing…',
#  'From Scratch: A Memoir of Love…',
#  'Erotic Stories for Punjabi…',
#  "You Think It, I'll Say It:…",
#  'Happiness: The Crooked Little…',
#  'This Is the Story of a Happy…',
#  'Still Lives']

# %% [markdown]
# ### Oprah Bookclub

# %%
oprahbooks=[]

for page in range(0,7):
    url = f'https://www.barnesandnoble.com/b/books/book-club-selections/oprahs-book-club/_/N-1fZ29Z8q8Z1qld?Nrpp=40&Ns=P_Publication_Date%7C1&page={page}#'
    resp = urllib.request.urlopen(url)
    soup = BS(resp, from_encoding=resp.info().get_param('charset'))
    for info in soup.find_all(class_='product-shelf-title product-info-title pt-xs'):
        book = info.get_text(strip=True)
        oprahbooks.append(book)

# %%
oprahbooks
# Out:
# ['The Good Earth',
#  'Olive, Again',
#  "Olive, Again (Oprah's Book…",
#  'Olive, Again',
#  "The Water Dancer (Oprah's Book…",
#  "The Water Dancer (Oprah's Book…",
#  "The Water Dancer (Oprah's Book…",
#  'The Water Dancer',
#  'The Sun Does Shine: How I…',
#  'An American Marriage',
#  'An American Marriage',
#  'Becoming',
#  'Becoming',
#  'Becoming',
#  'Becoming',
#  'House of Sand and Fog: A Novel',
#  'The Good Earth',
#  'The Sun Does Shine: How I…',
#  'The Sun Does Shine: How I…',
#  'The Sun Does Shine: How I…',
#  'The Sun Does Shine: How I…',
#  'The Sun Does Shine: How I…',
#  'An American Marriage',
#  "An American Marriage (Oprah's…",
#  "An American Marriage (Oprah's…",
#  "An American Marriage (Oprah's…",
#  "An American Marriage (Oprah's…",
#  'The Underground Railroad',
#  'Songs in Ordinary Time: A…',
#  'Songs in Ordinary Time: A…',
#  'Night',
#  'Night',
#  'Love Warrior',
#  'The Invention of Wings',
#  'River, Cross My Heart',
#  'Behold the Dreamers (Oprah…',
#  'The Good Earth',
#  'The Good Earth',
#  "Behold the Dreamers (Oprah's…",
#  'The Pillars of the Earth…',
#  'The Good Earth',
#  'Olive, Again',
#  "Olive, Again (Oprah's Book…",
#  'Olive, Again',
#  "The Water Dancer (Oprah's Book…",
#  "The Water Dancer (Oprah's Book…",
#  "The Water Dancer (Oprah's Book…",
#  'The Water Dancer',
#  'The Sun Does Shine: How I…',
#  'An American Marriage',
#  'An American Marriage',
#  'Becoming',
#  'Becoming',
#  'Becoming',
#  'Becoming',
#  'House of Sand and Fog: A Novel',
#  'The Good Earth',
#  'The Sun Does Shine: How I…',
#  'The Sun Does Shine: How I…',
#  'The Sun Does Shine: How I…',
#  'The Sun Does Shine: How I…',
#  'The Sun Does Shine: How I…',
#  'An American Marriage',
#  "An American Marriage (Oprah's…",
#  "An American Marriage (Oprah's…",
#  "An American Marriage (Oprah's…",
#  "An American Marriage (Oprah's…",
#  'The Underground Railroad',
#  'Songs in Ordinary Time: A…',
#  'Songs in Ordinary Time: A…',
#  'Night',
#  'Night',
#  'Love Warrior',
#  'The Invention of Wings',
#  'River, Cross My Heart',
#  'Behold the Dreamers (Oprah…',
#  'The Good Earth',
#  'The Good Earth',
#  "Behold the Dreamers (Oprah's…",
#  'The Pillars of the Earth…',
#  'Behold the Dreamers',
#  'East of Eden: (Penguin Orange…',
#  'Love Warrior',
#  'Love Warrior',
#  'Love Warrior',
#  "Love Warrior (Oprah's Book…",
#  'Behold the Dreamers',
#  "Behold the Dreamers (Oprah's…",
#  'Behold the Dreamers',
#  'The Underground Railroad…',
#  'The Underground Railroad…',
#  'The Underground Railroad…',
#  'The Underground Railroad…',
#  'The Pillars of the Earth…',
#  'Here on Earth',
#  'The Road',
#  'Where the Heart Is',
#  'The Invention of Wings',
#  'Breath, Eyes, Memory',
#  'Ruby',
#  'Ruby (Enhanced Edition)',
#  'A Tale of Two Cities and Great…',
#  'The Good Earth',
#  'The Poisonwood Bible',
#  'Love in the Time of Cholera',
#  'The Book of Ruth',
#  'Ruby',
#  'One Hundred Years of Solitude',
#  'Daughter of Fortune',
#  'Paradise',
#  'The Invention of Wings: A…',
#  'The Invention of Wings',
#  'The Invention of Wings: With…',
#  'Invention of Wings',
#  'The Twelve Tribes of Hattie',
#  "The Pilot's Wife",
#  'Love in the Time of Cholera',
#  'Night',
#  'Wild: From Lost to Found on…',
#  'Wild: From Lost to Found on…',
#  'Wild: From Lost to Found on…',
#  'Songs in Ordinary Time',
#  'The Twelve Tribes of Hattie',
#  'The Twelve Tribes of Hattie…',
#  'Ellen Foster',
#  "Ellen Foster (Oprah's Book…",
#  'Freedom',
#  'The Good Earth',
#  'Gap Creek',
#  'Gap Creek',
#  "Wild (Oprah's Book Club 2.0…",
#  'Wild: From Lost to Found on…',
#  'Night',
#  'Jewel',
#  'Freedom',
#  'Freedom',
#  'East of Eden',
#  "She's Come Undone",
#  'House of Sand and Fog',
#  'A Tale of Two Cities and Great…',
#  'A Tale of Two Cities and Great…',
#  'Stones from the River',
#  'Fall on Your Knees',
#  'A Map of the World',
#  'A Tale of Two Cities and Great…',
#  'A Tale of Two Cities and Great…',
#  'Freedom',
#  'Here on Earth',
#  'The Poisonwood Bible',
#  'Freedom',
#  'Freedom',
#  'Black and Blue: A Novel',
#  'The Heart Is a Lonely Hunter',
#  'A Fine Balance',
#  'The Pillars of the Earth…',
#  'Black and Blue',
#  'The Story of Edgar Sawtelle',
#  'The Poisonwood Bible',
#  'The Measure of a Man: A…',
#  'Vinegar Hill',
#  "Say You're One of Them",
#  "Say You're One of Them",
#  'The Story of Edgar Sawtelle',
#  'Here on Earth',
#  'The Heart of a Woman',
#  'The Heart of a Woman',
#  'I Know This Much Is True: A…',
#  'What Looks like Crazy on an…',
#  'Drowning Ruth',
#  'The Road (Movie Tie In Edition…',
#  "She's Come Undone",
#  'The Poisonwood Bible',
#  'Daughter of Fortune: A Novel',
#  "Say You're One of Them",
#  'Cry, the Beloved Country',
#  'I Know This Much Is True',
#  'A New Earth: Awakening to Your…',
#  'A New Earth: Awakening to Your…',
#  'The Pillars of the Earth…',
#  'Love in the Time of Cholera',
#  'The Pillars of the Earth…',
#  'Tara Road',
#  "The Pilot's Wife",
#  'Paradise',
#  'Song of Solomon',
#  'Sula',
#  'The Bluest Eye',
#  'The Good Earth',
#  'Middlesex',
#  'Tara Road',
#  'The Bluest Eye',
#  'The Road (Turtleback School &…',
#  'The Road',
#  'The Road',
#  'The Road',
#  'The Measure of a Man: A…',
#  'The Measure of a Man: A…',
#  'The Measure of a Man: A…',
#  'The Road',
#  'White Oleander',
#  'A New Earth: Awakening to Your…',
#  'One Hundred Years of Solitude',
#  'Daughter of Fortune',
#  'Vinegar Hill',
#  'One Hundred Years of Solitude …',
#  'One Hundred Years of Solitude',
#  'Night (Turtleback School &…',
#  'Night',
#  'A New Earth: Awakening to Your…',
#  'A Million Little Pieces',
#  'The Poisonwood Bible',
#  'A Summer of Faulkner: Three…',
#  'Cane River',
#  'The Good Earth',
#  'The Good Earth (Turtleback…',
#  'The Heart Is a Lonely Hunter',
#  'Sula',
#  'Song of Solomon',
#  'Back Roads',
#  'Song of Solomon',
#  'Anna Karenina…',
#  'Anna Karenina…',
#  'A Million Little Pieces',
#  'The Heart Is a Lonely Hunter',
#  'A Lesson before Dying',
#  'Cry, the Beloved Country',
#  'Cry, the Beloved Country',
#  'Cry, the Beloved Country',
#  'Cry, the Beloved Country',
#  'East of Eden',
#  'East of Eden',
#  'A Million Little Pieces',
#  'Middlesex',
#  'The Corrections',
#  'The Corrections',
#  'Midwives',
#  'Cane River',
#  'Sula',
#  'Fall on Your Knees',
#  'East of Eden',
#  'Fall on Your Knees',
#  'A Fine Balance',
#  'The Corrections',
#  'Drowning Ruth',
#  'The Reader',
#  'Open House',
#  'Cane River',
#  'Where the Heart Is',
#  'Icy Sparks',
#  'Icy Sparks',
#  'Icy Sparks',
#  'The Heart Is a Lonely Hunter',
#  'Song of Solomon',
#  'We Were the Mulvaneys',
#  'We Were the Mulvaneys',
#  'Back Roads',
#  'Open House',
#  'Drowning Ruth',
#  'Open House',
#  'Daughter of Fortune',
#  'Tara Road',
#  'Mother of Pearl',
#  'While I Was Gone',
#  'White Oleander',
#  'Gap Creek: The Story of a…',
#  'A Map of the World',
#  'The Deep End of the Ocean',
#  'Here on Earth',
#  'Here on Earth',
#  "The Pilot's Wife",
#  'The Reader (Turtleback School …',
#  'Where the Heart Is',
#  'The Reader',
#  'Jewel',
#  'Midwives',
#  'The Poisonwood Bible',
#  'Where the Heart Is',
#  "The Pilot's Wife",
#  'Here on Earth',
#  'Paradise']
